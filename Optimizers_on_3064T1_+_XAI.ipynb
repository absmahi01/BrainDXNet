# %%
import os
import shutil
import itertools
import pathlib
from PIL import Image
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.regularizers import l2
#Data handling tools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix , classification_report

#Deep learning libs
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D , MaxPooling2D , Flatten , Activation , Dense , Dropout , BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adadelta, Adagrad, Adam, Adamax, Nadam, SGD, RMSprop

#Warningds
import warnings
warnings.filterwarnings('ignore')

# %%
train_data_path = "F:\\Mahi\\brain mri\\T1 3064 blurred\\train"

filepaths =[]

labels = []

folds = os.listdir(train_data_path)

for fold in folds:
    f_path = os.path.join(train_data_path , fold)
    filelists = os.listdir(f_path)

    for file in filelists:
        filepaths.append(os.path.join(f_path , file))
        labels.append(fold)

#Concat data paths with labels
Fseries = pd.Series(filepaths , name = 'filepaths')
Lseries = pd.Series(labels , name = 'label')
train_df = pd.concat([Fseries , Lseries] , axis = 1)

# %%
test_data_path = "F:\\Mahi\\brain mri\\T1 3064 blurred\\test"


filepaths =[]
labels = []

folds = os.listdir(test_data_path)

for fold in folds:
    f_path = os.path.join(test_data_path , fold)
    filelists = os.listdir(f_path)

    for file in filelists:
        filepaths.append(os.path.join(f_path , file))
        labels.append(fold)

#Concat data paths with labels
Fseries = pd.Series(filepaths , name = 'filepaths')
Lseries = pd.Series(labels , name = 'label')
test_df = pd.concat([Fseries , Lseries] , axis = 1)

# %%
from keras.preprocessing.image import ImageDataGenerator
img_size = (224 ,224)
batch_size = 16

ts_gen= ImageDataGenerator()

tr_gen= ImageDataGenerator()
# Create an instance of the ImageDataGenerator

train_gen = tr_gen.flow_from_dataframe(train_df , x_col = 'filepaths' , y_col = 'label' , target_size = img_size ,
                                      class_mode = 'categorical' , color_mode = 'rgb' , shuffle = True , batch_size =batch_size)
test_gen = ts_gen.flow_from_dataframe(test_df , x_col= 'filepaths' , y_col = 'label' , target_size = img_size, class_mode = 'categorical' ,
                                      color_mode= 'rgb', shuffle = False , batch_size = batch_size)
# Out:
# Found 2451 validated image filenames belonging to 3 classes.
# Found 613 validated image filenames belonging to 3 classes.

# %%
gen_dict = train_gen.class_indices
classes = list(gen_dict.keys())
images , labels = next(train_gen)

plt.figure(figsize= (20,20))

for i in range(16):
    plt.subplot(4,4,i+1)
    image = images[i] / 255
    plt.imshow(image)
    index = np.argmax(labels[i])
    class_name = classes[index]
    plt.title(class_name , color = 'blue' , fontsize= 12)
    plt.axis('off')
#plt.savefig("/content/drive/MyDrive/Dataset.jpg")
plt.show();
# plt.savefig("/content/drive/MyDrive/Dataset.jpg")

# %%
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
# Specify the path to save the best model weights
checkpoint_filepath = 'F:\\Mahi\\brain mri\\cnn7022.h5'
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.0001)
# Set up the ModelCheckpoint callback to save weights with the highest validation accuracy
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

# %%
#Adam

# %%
#Best so far
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.layers.experimental import preprocessing

model2 = Sequential()# contrast change by up to 50%)

# Convolutional layer 1
model2.add(Conv2D(64, (4, 4), activation="relu", input_shape=(224, 224, 3), padding='same'))
model2.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model2.add(BatchNormalization())
#conv2
model2.add(Conv2D(64,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

#Convolutional layer 3
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 4
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 5
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

 # Convolutional layer 6
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(GlobalAveragePooling2D())

# Full connect layers

model2.add(Dense(units= 1024, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=512, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=3, activation='softmax'))



model2.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy',
                   metrics=['accuracy'])
history = model2.fit(
    x=train_gen,
    epochs = 100,
    validation_data = test_gen,
    steps_per_epoch=119,
    callbacks=[reduce_lr, model_checkpoint_callback])
#keras.utils.plot_model(model2, to_file='CNN 95.56%_model_architecture.png',show_shapes=True,)

# %%
model2.load_weights("F:/Mahi/brain mri/cnn7022.h5")
preds = model2.predict_generator(test_gen)
y_pred = np.argmax(preds , axis = 1)
print(classification_report(y_pred,test_gen.classes,digits=6))

# %% [markdown]
# #
# Adamax

# %%
#Best so far
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.layers.experimental import preprocessing

model2 = Sequential()

# Convolutional layer 1
model2.add(Conv2D(64, (4, 4), activation="relu", input_shape=(224, 224, 3), padding='same'))
model2.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model2.add(BatchNormalization())
#conv2
model2.add(Conv2D(64,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

#Convolutional layer 3
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 4
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 5
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

 # Convolutional layer 6
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(GlobalAveragePooling2D())

# Full connect layers

model2.add(Dense(units= 1024, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=512, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=3, activation='softmax'))



model2.compile(optimizer=Adamax(learning_rate=0.001), loss='categorical_crossentropy',
                   metrics=['accuracy'])
history = model2.fit(
    x=train_gen,
    epochs = 100,
    validation_data = test_gen,
    steps_per_epoch=119,
   # epochs=15,
    #validation_data=test_generator,
    #validation_steps=69,
    callbacks=[reduce_lr, model_checkpoint_callback])
#keras.utils.plot_model(model2, to_file='CNN 95.56%_model_architecture.png',show_shapes=True,)
# Out:
# Epoch 1/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6012 - accuracy: 0.7530
# Epoch 1: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 14s 107ms/step - loss: 0.6012 - accuracy: 0.7530 - val_loss: 1.6881 - val_accuracy: 0.3116 - lr: 0.0010
# Epoch 2/100
# 119/119 [==============================] - ETA: 0s - loss: 0.3776 - accuracy: 0.8493
# Epoch 2: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 0.3776 - accuracy: 0.8493 - val_loss: 1.2819 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 3/100
# 119/119 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9001
# Epoch 3: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 102ms/step - loss: 0.2424 - accuracy: 0.9001 - val_loss: 1.7199 - val_accuracy: 0.5449 - lr: 0.0010
# Epoch 4/100
# 119/119 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9201
# Epoch 4: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 0.1983 - accuracy: 0.9201 - val_loss: 1.4595 - val_accuracy: 0.6982 - lr: 0.0010
# Epoch 5/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.1350 - accuracy: 0.9449
# Epoch 5: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.1350 - accuracy: 0.9450 - val_loss: 0.3418 - val_accuracy: 0.8728 - lr: 0.0010
# Epoch 6/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9680
# Epoch 6: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0947 - accuracy: 0.9680 - val_loss: 1.5458 - val_accuracy: 0.7178 - lr: 0.0010
# Epoch 7/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9627
# Epoch 7: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0936 - accuracy: 0.9627 - val_loss: 0.6667 - val_accuracy: 0.8026 - lr: 0.0010
# Epoch 8/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9773
# Epoch 8: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0616 - accuracy: 0.9773 - val_loss: 0.3734 - val_accuracy: 0.8956 - lr: 0.0010
# Epoch 9/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9720
# Epoch 9: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0853 - accuracy: 0.9720 - val_loss: 0.5660 - val_accuracy: 0.8287 - lr: 0.0010
# Epoch 10/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9878
# Epoch 10: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 105ms/step - loss: 0.0343 - accuracy: 0.9878 - val_loss: 0.5311 - val_accuracy: 0.8695 - lr: 0.0010
# Epoch 11/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9968
# Epoch 11: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.5961 - val_accuracy: 0.8646 - lr: 2.0000e-04
# Epoch 12/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9974
# Epoch 12: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.3907 - val_accuracy: 0.9021 - lr: 2.0000e-04
# Epoch 13/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9995
# Epoch 13: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.3883 - val_accuracy: 0.9103 - lr: 2.0000e-04
# Epoch 14/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9995
# Epoch 14: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.4443 - val_accuracy: 0.8940 - lr: 2.0000e-04
# Epoch 15/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9989
# Epoch 15: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.4534 - val_accuracy: 0.9005 - lr: 2.0000e-04
# Epoch 16/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4427 - val_accuracy: 0.9005 - lr: 1.0000e-04
# Epoch 17/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995
# Epoch 17: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.4614 - val_accuracy: 0.8956 - lr: 1.0000e-04
# Epoch 18/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9995
# Epoch 18: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.4567 - val_accuracy: 0.9005 - lr: 1.0000e-04
# Epoch 19/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 20/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4192 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 21/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 21: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.4589 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 22/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4645 - val_accuracy: 0.9005 - lr: 1.0000e-04
# Epoch 23/100
# 119/119 [==============================] - ETA: 0s - loss: 9.9474e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 102ms/step - loss: 9.9474e-04 - accuracy: 1.0000 - val_loss: 0.4248 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 24/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 24: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.4219 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 25/100
# 119/119 [==============================] - ETA: 0s - loss: 8.2041e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 8.2041e-04 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 26/100
# 119/119 [==============================] - ETA: 0s - loss: 9.4362e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 9.4362e-04 - accuracy: 1.0000 - val_loss: 0.5326 - val_accuracy: 0.8989 - lr: 1.0000e-04
# Epoch 27/100
# 119/119 [==============================] - ETA: 0s - loss: 7.7851e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 7.7851e-04 - accuracy: 1.0000 - val_loss: 0.4782 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 28/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9989
# Epoch 28: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.4677 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 29/100
# 119/119 [==============================] - ETA: 0s - loss: 5.4040e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 105ms/step - loss: 5.4040e-04 - accuracy: 1.0000 - val_loss: 0.4835 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 30/100
# 119/119 [==============================] - ETA: 0s - loss: 5.9474e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 5.9474e-04 - accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.9054 - lr: 1.0000e-04
# Epoch 31/100
# 119/119 [==============================] - ETA: 0s - loss: 3.7261e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 3.7261e-04 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 32/100
# 119/119 [==============================] - ETA: 0s - loss: 6.0358e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 6.0358e-04 - accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 33/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 33: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.5191 - val_accuracy: 0.8972 - lr: 1.0000e-04
# Epoch 34/100
# 119/119 [==============================] - ETA: 0s - loss: 4.4147e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 4.4147e-04 - accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 0.8989 - lr: 1.0000e-04
# Epoch 35/100
# 119/119 [==============================] - ETA: 0s - loss: 5.4815e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 5.4815e-04 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 36/100
# 119/119 [==============================] - ETA: 0s - loss: 2.2785e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 2.2785e-04 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 37/100
# 119/119 [==============================] - ETA: 0s - loss: 8.8643e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 8.8643e-04 - accuracy: 1.0000 - val_loss: 0.4447 - val_accuracy: 0.9168 - lr: 1.0000e-04
# Epoch 38/100
# 119/119 [==============================] - ETA: 0s - loss: 6.8166e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 6.8166e-04 - accuracy: 1.0000 - val_loss: 0.4648 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 39/100
# 119/119 [==============================] - ETA: 0s - loss: 4.3868e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 4.3868e-04 - accuracy: 1.0000 - val_loss: 0.4691 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 40/100
# 119/119 [==============================] - ETA: 0s - loss: 2.6895e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 2.6895e-04 - accuracy: 1.0000 - val_loss: 0.4532 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 41/100
# 119/119 [==============================] - ETA: 0s - loss: 3.4713e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 3.4713e-04 - accuracy: 1.0000 - val_loss: 0.4438 - val_accuracy: 0.9135 - lr: 1.0000e-04
# Epoch 42/100
# 119/119 [==============================] - ETA: 0s - loss: 4.1776e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 4.1776e-04 - accuracy: 1.0000 - val_loss: 0.4504 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 43/100
# 119/119 [==============================] - ETA: 0s - loss: 3.3350e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 3.3350e-04 - accuracy: 1.0000 - val_loss: 0.4999 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 44/100
# 119/119 [==============================] - ETA: 0s - loss: 7.4412e-04 - accuracy: 0.9995
# Epoch 44: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 106ms/step - loss: 7.4412e-04 - accuracy: 0.9995 - val_loss: 0.6205 - val_accuracy: 0.8989 - lr: 1.0000e-04
# Epoch 45/100
# 119/119 [==============================] - ETA: 0s - loss: 5.1318e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 5.1318e-04 - accuracy: 1.0000 - val_loss: 0.5104 - val_accuracy: 0.9135 - lr: 1.0000e-04
# Epoch 46/100
# 119/119 [==============================] - ETA: 0s - loss: 2.1343e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 2.1343e-04 - accuracy: 1.0000 - val_loss: 0.4864 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 47/100
# 119/119 [==============================] - ETA: 0s - loss: 9.8493e-05 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 9.8493e-05 - accuracy: 1.0000 - val_loss: 0.4931 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 48/100
# 119/119 [==============================] - ETA: 0s - loss: 1.3113e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 1.3113e-04 - accuracy: 1.0000 - val_loss: 0.4987 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 49/100
# 119/119 [==============================] - ETA: 0s - loss: 3.4814e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 3.4814e-04 - accuracy: 1.0000 - val_loss: 0.6591 - val_accuracy: 0.8907 - lr: 1.0000e-04
# Epoch 50/100
# 119/119 [==============================] - ETA: 0s - loss: 7.4779e-04 - accuracy: 0.9995
# Epoch 50: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 7.4779e-04 - accuracy: 0.9995 - val_loss: 0.6046 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 51/100
# 119/119 [==============================] - ETA: 0s - loss: 2.5628e-04 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 2.5628e-04 - accuracy: 1.0000 - val_loss: 0.5468 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 52/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989
# Epoch 52: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.5465 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 53/100
# 119/119 [==============================] - ETA: 0s - loss: 2.3846e-04 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 2.3846e-04 - accuracy: 1.0000 - val_loss: 0.5030 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 54/100
# 119/119 [==============================] - ETA: 0s - loss: 3.5831e-04 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 3.5831e-04 - accuracy: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 55/100
# 119/119 [==============================] - ETA: 0s - loss: 1.2317e-04 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 1.2317e-04 - accuracy: 1.0000 - val_loss: 0.4823 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 56/100
# 119/119 [==============================] - ETA: 0s - loss: 1.1349e-04 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 1.1349e-04 - accuracy: 1.0000 - val_loss: 0.4691 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 57/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995
# Epoch 57: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.4923 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 58/100
# 119/119 [==============================] - ETA: 0s - loss: 1.8388e-04 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 1.8388e-04 - accuracy: 1.0000 - val_loss: 0.4971 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 59/100
# 119/119 [==============================] - ETA: 0s - loss: 2.6761e-04 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 2.6761e-04 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 60/100
# 119/119 [==============================] - ETA: 0s - loss: 5.4293e-04 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 5.4293e-04 - accuracy: 1.0000 - val_loss: 0.5588 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 61/100
# 119/119 [==============================] - ETA: 0s - loss: 1.9744e-04 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 1.9744e-04 - accuracy: 1.0000 - val_loss: 0.5420 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 62/100
# 119/119 [==============================] - ETA: 0s - loss: 1.0430e-04 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 1.0430e-04 - accuracy: 1.0000 - val_loss: 0.5267 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 63/100
# 119/119 [==============================] - ETA: 0s - loss: 8.1465e-05 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 8.1465e-05 - accuracy: 1.0000 - val_loss: 0.5205 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 64/100
# 119/119 [==============================] - ETA: 0s - loss: 8.7589e-04 - accuracy: 0.9995
# Epoch 64: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 8.7589e-04 - accuracy: 0.9995 - val_loss: 0.5292 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 65/100
# 119/119 [==============================] - ETA: 0s - loss: 5.6752e-04 - accuracy: 0.9995
# Epoch 65: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 5.6752e-04 - accuracy: 0.9995 - val_loss: 0.5078 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 66/100
# 119/119 [==============================] - ETA: 0s - loss: 8.3294e-05 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 104ms/step - loss: 8.3294e-05 - accuracy: 1.0000 - val_loss: 0.5134 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 67/100
# 119/119 [==============================] - ETA: 0s - loss: 1.4044e-04 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 106ms/step - loss: 1.4044e-04 - accuracy: 1.0000 - val_loss: 0.5640 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 68/100
# 119/119 [==============================] - ETA: 0s - loss: 1.6850e-04 - accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 1.6850e-04 - accuracy: 1.0000 - val_loss: 0.5387 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 69/100
# 119/119 [==============================] - ETA: 0s - loss: 1.6519e-04 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 1.6519e-04 - accuracy: 1.0000 - val_loss: 0.5352 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 70/100
# 119/119 [==============================] - ETA: 0s - loss: 2.2954e-04 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 2.2954e-04 - accuracy: 1.0000 - val_loss: 0.5484 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 71/100
# 119/119 [==============================] - ETA: 0s - loss: 2.9944e-05 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 2.9944e-05 - accuracy: 1.0000 - val_loss: 0.5527 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 72/100
# 119/119 [==============================] - ETA: 0s - loss: 4.9017e-05 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 4.9017e-05 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 73/100
# 119/119 [==============================] - ETA: 0s - loss: 1.6218e-04 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 1.6218e-04 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 74/100
# 119/119 [==============================] - ETA: 0s - loss: 2.7792e-04 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 2.7792e-04 - accuracy: 1.0000 - val_loss: 0.5388 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 75/100
# 119/119 [==============================] - ETA: 0s - loss: 7.2413e-05 - accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 7.2413e-05 - accuracy: 1.0000 - val_loss: 0.5835 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 76/100
# 119/119 [==============================] - ETA: 0s - loss: 6.1443e-05 - accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 6.1443e-05 - accuracy: 1.0000 - val_loss: 0.5894 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 77/100
# 118/119 [============================>.] - ETA: 0s - loss: 4.0162e-05 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 4.5438e-05 - accuracy: 1.0000 - val_loss: 0.5732 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 78/100
# 119/119 [==============================] - ETA: 0s - loss: 3.1745e-05 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 3.1745e-05 - accuracy: 1.0000 - val_loss: 0.5573 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 79/100
# 119/119 [==============================] - ETA: 0s - loss: 4.8630e-05 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 4.8630e-05 - accuracy: 1.0000 - val_loss: 0.5614 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 80/100
# 119/119 [==============================] - ETA: 0s - loss: 1.5396e-04 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 1.5396e-04 - accuracy: 1.0000 - val_loss: 0.5688 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 81/100
# 119/119 [==============================] - ETA: 0s - loss: 2.6647e-05 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 2.6647e-05 - accuracy: 1.0000 - val_loss: 0.5629 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 82/100
# 119/119 [==============================] - ETA: 0s - loss: 6.0264e-05 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 6.0264e-05 - accuracy: 1.0000 - val_loss: 0.5701 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 83/100
# 119/119 [==============================] - ETA: 0s - loss: 4.3647e-05 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 106ms/step - loss: 4.3647e-05 - accuracy: 1.0000 - val_loss: 0.5864 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 84/100
# 119/119 [==============================] - ETA: 0s - loss: 4.0917e-05 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 4.0917e-05 - accuracy: 1.0000 - val_loss: 0.5836 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 85/100
# 119/119 [==============================] - ETA: 0s - loss: 1.2570e-05 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 1.2570e-05 - accuracy: 1.0000 - val_loss: 0.5822 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 86/100
# 119/119 [==============================] - ETA: 0s - loss: 1.6796e-04 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 1.6796e-04 - accuracy: 1.0000 - val_loss: 0.7474 - val_accuracy: 0.8956 - lr: 1.0000e-04
# Epoch 87/100
# 119/119 [==============================] - ETA: 0s - loss: 4.0579e-05 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 4.0579e-05 - accuracy: 1.0000 - val_loss: 0.6238 - val_accuracy: 0.9054 - lr: 1.0000e-04
# Epoch 88/100
# 119/119 [==============================] - ETA: 0s - loss: 3.4543e-04 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 105ms/step - loss: 3.4543e-04 - accuracy: 1.0000 - val_loss: 0.6327 - val_accuracy: 0.9054 - lr: 1.0000e-04
# Epoch 89/100
# 119/119 [==============================] - ETA: 0s - loss: 3.9252e-05 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 3.9252e-05 - accuracy: 1.0000 - val_loss: 0.6324 - val_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 90/100
# 119/119 [==============================] - ETA: 0s - loss: 6.5646e-04 - accuracy: 0.9995
# Epoch 90: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 6.5646e-04 - accuracy: 0.9995 - val_loss: 0.6567 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 91/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9995
# Epoch 91: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.6161 - val_accuracy: 0.9135 - lr: 1.0000e-04
# Epoch 92/100
# 119/119 [==============================] - ETA: 0s - loss: 1.9948e-05 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 1.9948e-05 - accuracy: 1.0000 - val_loss: 0.6223 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 93/100
# 119/119 [==============================] - ETA: 0s - loss: 4.3022e-05 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 106ms/step - loss: 4.3022e-05 - accuracy: 1.0000 - val_loss: 0.6217 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 94/100
# 119/119 [==============================] - ETA: 0s - loss: 8.7015e-05 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 8.7015e-05 - accuracy: 1.0000 - val_loss: 0.6220 - val_accuracy: 0.9152 - lr: 1.0000e-04
# Epoch 95/100
# 119/119 [==============================] - ETA: 0s - loss: 3.8383e-05 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 3.8383e-05 - accuracy: 1.0000 - val_loss: 0.6238 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 96/100
# 119/119 [==============================] - ETA: 0s - loss: 5.1172e-05 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 104ms/step - loss: 5.1172e-05 - accuracy: 1.0000 - val_loss: 0.6222 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 97/100
# 119/119 [==============================] - ETA: 0s - loss: 3.3281e-05 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 3.3281e-05 - accuracy: 1.0000 - val_loss: 0.6167 - val_accuracy: 0.9135 - lr: 1.0000e-04
# Epoch 98/100
# 119/119 [==============================] - ETA: 0s - loss: 2.1116e-05 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 2.1116e-05 - accuracy: 1.0000 - val_loss: 0.6170 - val_accuracy: 0.9135 - lr: 1.0000e-04
# Epoch 99/100
# 119/119 [==============================] - ETA: 0s - loss: 1.3837e-05 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 12s 103ms/step - loss: 1.3837e-05 - accuracy: 1.0000 - val_loss: 0.6190 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 100/100
# 119/119 [==============================] - ETA: 0s - loss: 1.5339e-04 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 0.93964
# 119/119 [==============================] - 13s 105ms/step - loss: 1.5339e-04 - accuracy: 1.0000 - val_loss: 0.6081 - val_accuracy: 0.9135 - lr: 1.0000e-04

# %%
model2.load_weights("F:/Mahi/brain mri/cnn7022.h5")
preds = model2.predict_generator(test_gen)
y_pred = np.argmax(preds , axis = 1)
print(classification_report(y_pred,test_gen.classes,digits=6))
# Out:
#               precision    recall  f1-score   support
#
#            0   0.873239  0.885714  0.879433       140
#            1   0.964912  0.945017  0.954861       291
#            2   0.951613  0.972527  0.961957       182
#
#     accuracy                       0.939641       613
#    macro avg   0.929922  0.934420  0.932083       613
# weighted avg   0.940027  0.939641  0.939741       613

# %% [markdown]
# Adadelta

# %%
#Best so far
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.layers.experimental import preprocessing

model2 = Sequential()

# Convolutional layer 1
model2.add(Conv2D(64, (4, 4), activation="relu", input_shape=(224, 224, 3), padding='same'))
model2.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model2.add(BatchNormalization())
#conv2
model2.add(Conv2D(64,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

#Convolutional layer 3
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 4
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 5
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

 # Convolutional layer 6
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(GlobalAveragePooling2D())

# Full connect layers

model2.add(Dense(units= 1024, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=512, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=3, activation='softmax'))



model2.compile(optimizer=Adadelta(learning_rate=0.001), loss='categorical_crossentropy',
                   metrics=['accuracy'])
history = model2.fit(
    x=train_gen,
    epochs = 100,
    validation_data = test_gen,
    steps_per_epoch=119,
   # epochs=15,
    #validation_data=test_generator,
    #validation_steps=69,
    callbacks=[reduce_lr, model_checkpoint_callback])
#keras.utils.plot_model(model2, to_file='CNN 95.56%_model_architecture.png',show_shapes=True,)

# %%
model2.load_weights("F:/Mahi/brain mri/cnn7022.h5")
preds = model2.predict_generator(test_gen)
y_pred = np.argmax(preds , axis = 1)
print(classification_report(y_pred,test_gen.classes,digits=6))

# %% [markdown]
# Adagrad

# %%
#Best so far
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.layers.experimental import preprocessing

model2 = Sequential()# contrast change by up to 50%)

# Convolutional layer 1
model2.add(Conv2D(64, (4, 4), activation="relu", input_shape=(224, 224, 3), padding='same'))
model2.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model2.add(BatchNormalization())
#conv2
model2.add(Conv2D(64,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

#Convolutional layer 3
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 4
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 5
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

 # Convolutional layer 6
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(GlobalAveragePooling2D())

# Full connect layers

model2.add(Dense(units= 1024, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=512, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=3, activation='softmax'))



model2.compile(optimizer=Adagrad(learning_rate=0.001), loss='categorical_crossentropy',
                   metrics=['accuracy'])
history = model2.fit(
    x=train_gen,
    epochs = 100,
    validation_data = test_gen,
    steps_per_epoch=119,
   # epochs=15,
    #validation_data=test_generator,
    #validation_steps=69,
    callbacks=[reduce_lr, model_checkpoint_callback])
#keras.utils.plot_model(model2, to_file='CNN 95.56%_model_architecture.png',show_shapes=True,)

# %%
model2.load_weights("F:/Mahi/brain mri/cnn7022.h5")
preds = model2.predict_generator(test_gen)
y_pred = np.argmax(preds , axis = 1)
print(classification_report(y_pred,test_gen.classes,digits=6))

# %% [markdown]
# Nadam

# %%
#Best so far
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.layers.experimental import preprocessing

model2 = Sequential()# contrast change by up to 50%)

# Convolutional layer 1
model2.add(Conv2D(64, (4, 4), activation="relu", input_shape=(224, 224, 3), padding='same'))
model2.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model2.add(BatchNormalization())
#conv2
model2.add(Conv2D(64,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

#Convolutional layer 3
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 4
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 5
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

 # Convolutional layer 6
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(GlobalAveragePooling2D())

# Full connect layers

model2.add(Dense(units= 1024, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=512, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=3, activation='softmax'))



model2.compile(optimizer=Nadam(learning_rate=0.001), loss='categorical_crossentropy',
                   metrics=['accuracy'])
history = model2.fit(
    x=train_gen,
    epochs = 100,
    validation_data = test_gen,
    steps_per_epoch=119,
   # epochs=15,
    #validation_data=test_generator,
    #validation_steps=69,
    callbacks=[reduce_lr, model_checkpoint_callback])
#keras.utils.plot_model(model2, to_file='CNN 95.56%_model_architecture.png',show_shapes=True,)

# %%
model2.load_weights("F:/Mahi/brain mri/cnn7022.h5")
preds = model2.predict_generator(test_gen)
y_pred = np.argmax(preds , axis = 1)
print(classification_report(y_pred,test_gen.classes,digits=6))

# %% [markdown]
# SGD

# %%
#Best so far
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.layers.experimental import preprocessing

model2 = Sequential()# contrast change by up to 50%)

# Convolutional layer 1
model2.add(Conv2D(64, (4, 4), activation="relu", input_shape=(224, 224, 3), padding='same'))
model2.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model2.add(BatchNormalization())
#conv2
model2.add(Conv2D(64,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

#Convolutional layer 3
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 4
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 5
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

 # Convolutional layer 6
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(GlobalAveragePooling2D())

# Full connect layers

model2.add(Dense(units= 1024, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=512, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=3, activation='softmax'))



model2.compile(optimizer=SGD(learning_rate=0.001), loss='categorical_crossentropy',
                   metrics=['accuracy'])
history = model2.fit(
    x=train_gen,
    epochs = 100,
    validation_data = test_gen,
    steps_per_epoch=119,
   # epochs=15,
    #validation_data=test_generator,
    #validation_steps=69,
    callbacks=[reduce_lr, model_checkpoint_callback])
#keras.utils.plot_model(model2, to_file='CNN 95.56%_model_architecture.png',show_shapes=True,)

# %%
model2.load_weights("F:/Mahi/brain mri/cnn7022.h5")
preds = model2.predict_generator(test_gen)
y_pred = np.argmax(preds , axis = 1)
print(classification_report(y_pred,test_gen.classes,digits=6))

# %% [markdown]
# RMSprop

# %%
#Best so far
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.layers.experimental import preprocessing

model2 = Sequential()# contrast change by up to 50%)

# Convolutional layer 1
model2.add(Conv2D(64, (4, 4), activation="relu", input_shape=(224, 224, 3), padding='same'))
model2.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
model2.add(BatchNormalization())
#conv2
model2.add(Conv2D(64,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

#Convolutional layer 3
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 4
model2.add(Conv2D(128,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

# Convolutional layer 5
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())

 # Convolutional layer 6
model2.add(Conv2D(256,(4,4), padding='same', activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(GlobalAveragePooling2D())

# Full connect layers

model2.add(Dense(units= 1024, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=512, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(units=3, activation='softmax'))



model2.compile(optimizer=RMSprop(learning_rate=0.001), loss='categorical_crossentropy',
                   metrics=['accuracy'])
history = model2.fit(
    x=train_gen,
    epochs = 100,
    validation_data = test_gen,
    steps_per_epoch=119,
   # epochs=15,
    #validation_data=test_generator,
    #validation_steps=69,
    callbacks=[reduce_lr, model_checkpoint_callback])
#keras.utils.plot_model(model2, to_file='CNN 95.56%_model_architecture.png',show_shapes=True,)

# %%
model2.load_weights("F:/Mahi/brain mri/cnn7022.h5")
preds = model2.predict_generator(test_gen)
y_pred = np.argmax(preds , axis = 1)
print(classification_report(y_pred,test_gen.classes,digits=6))

# %% [markdown]
# #Grad Cam

# %%
import matplotlib.pyplot as plt

from tensorflow.keras.utils import load_img, img_to_array

from keras import backend as K
from scipy.ndimage import zoom
import numpy as np
import os
import tensorflow as tf
import keras
tf.compat.v1.disable_eager_execution()


def generate_cam(input_model, image, layer_name='block5_conv3', H=224, W=224):

    cls = np.argmax(input_model.predict(image)) # Obtain the predicted class
    conv_output = input_model.get_layer(layer_name).output #Get the weights of the last output layer

    last_conv_layer_model = keras.Model(input_model.inputs, conv_output) #Create a model with the last output layer
    class_weights = input_model.get_layer(layer_name).get_weights()[0] # Get the weights of the output layer\
    class_weights = class_weights[0,:,:,:]
    class_weights = np.mean(class_weights, axis=(0, 1))


    last_conv_output = last_conv_layer_model.predict(image) #The feature map output from last output layer
    last_conv_output = last_conv_output[0, :]
    cam = np.dot(last_conv_output, class_weights)


    cam = zoom(cam, H/cam.shape[0]) #Spatial Interpolation/zooming to image size
    cam = cam / np.max(cam) #Normalizing the gradcam

    return cam
def grad_cam(input_model, image, layer_name='block5_conv3',H=224,W=224):

    cls = np.argmax(input_model.predict(image)) #Get the predicted class
    y_c = input_model.output[0, cls] #Probability Score
    conv_output = input_model.get_layer(layer_name).output #Tensor of the last layer of cnn
    grads = K.gradients(y_c, conv_output)[0] #Gradients of the predicted class wrt conv_output layer

    get_output = K.function([input_model.input], [conv_output, grads])
    output, grads_val = get_output([image]) #Gives output of image till conv_output layer and the gradient values at that level
    output, grads_val = output[0, :], grads_val[0, :, :, :]


    weights = np.mean(grads_val, axis=(0, 1)) #Mean of gradients which acts as our weights
    cam = np.dot(output, weights) #Grad-CAM output

    cam = np.maximum(cam, 0) #Applying Relu
    cam = zoom(cam,H/cam.shape[0]) #Spatial Interpolation/zooming to image size
    cam = cam / cam.max() #Normalizing the gradcam

    return cam

# %%
def grad_cam_plus(input_model, image, layer_name='block5_conv3',H=224,W=224):

    cls = np.argmax(input_model.predict(image))
    y_c = input_model.output[0, cls]
    conv_output = input_model.get_layer(layer_name).output
    grads = K.gradients(y_c, conv_output)[0]

    first = K.exp(y_c)*grads #Variables used to calculate first second and third gradients
    second = K.exp(y_c)*grads*grads
    third = K.exp(y_c)*grads*grads*grads

    #Gradient calculation
    get_output = K.function([input_model.input], [y_c,first,second,third, conv_output, grads])
    y_c, conv_first_grad, conv_second_grad,conv_third_grad, conv_output, grads_val = get_output([img])
    global_sum = np.sum(conv_output[0].reshape((-1,conv_first_grad[0].shape[2])), axis=0)

    #Used to calculate the alpha values for each spatial location
    alpha_num = conv_second_grad[0]
    alpha_denom = conv_second_grad[0]*2.0 + conv_third_grad[0]*global_sum.reshape((1,1,conv_first_grad[0].shape[2]))
    alpha_denom = np.where(alpha_denom != 0.0, alpha_denom, np.ones(alpha_denom.shape))
    alphas = alpha_num/alpha_denom

    #Calculating the weights and alpha's which is the scale at which we multiply the weights with more importance
    weights = np.maximum(conv_first_grad[0], 0.0)
    alpha_normalization_constant = np.sum(np.sum(alphas, axis=0),axis=0)
    alphas /= alpha_normalization_constant.reshape((1,1,conv_first_grad[0].shape[2])) #Normalizing alpha

    #Weights with alpha multiplied to get spatial importance
    deep_linearization_weights = np.sum((weights*alphas).reshape((-1,conv_first_grad[0].shape[2])),axis=0)

    grad_CAM_map = np.sum(deep_linearization_weights*conv_output[0], axis=2) #Grad-CAM++ map
    cam = np.maximum(grad_CAM_map, 0)
    cam = zoom(cam,H/cam.shape[0])
    cam = cam / np.max(cam)

    return cam

# %%
images = ["F:\\Mahi\\brain mri\\T1 3064 blurred\\test\\pituitary\\Te-pi_0091.jpg"]

# %%
for path in images:

    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)

    top_n = 5
    top = decode_predictions(predictions, top=top_n)[0]
    cls = np.argsort(predictions[0])[-top_n:][::-1]

    cam = generate_cam(model,img)
    gradcam=grad_cam(model,img)
    gradcamplus=grad_cam_plus(model,img)

    print(path)
    print("class activation map for:",top[0])
    print(type(gradcam))

# If gradcam is not a numpy array, convert it
# For example, if gradcam is a PIL Image object:
# gradcam = np.array(gradcam)

# Check the data type and shape after conversion
    print(gradcam.dtype)
    print(gradcam.shape)

    fig, ax = plt.subplots(nrows=1,ncols=4)
    plt.subplot(141)
    plt.imshow(orig_img)
    plt.title("Input Image")
    plt.axis('off')
    plt.subplot(142)
    plt.imshow(orig_img)
    plt.imshow(cam,alpha=0.8,cmap="jet")
    plt.title("CAM")
    plt.axis('off')
    plt.subplot(143)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.8,cmap="jet")
    plt.title("Grad-CAM")
    plt.axis('off')
    plt.subplot(144)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.8,cmap="jet")
    plt.title("Grad-CAM++")
    plt.axis('off')
    plt.show()
